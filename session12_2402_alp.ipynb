# %%
set("alparslan")
# Out:
# {'a', 'l', 'n', 'p', 'r', 's'}

# %%
print(set("Erdemirel"))
# Out:
# {'d', 'r', 'i', 'm', 'l', 'e', 'E'}

# %%
set("mehmet")
# Out:
# {'e', 'h', 'm', 't'}

# %%
set("mavi","kirmizi", "beyaz", "mavi")   # HATA
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 set("mavi","kirmizi", "beyaz", "mavi")   # HATA
#
# TypeError: set expected at most 1 argument, got 4

# %%
aa=set("mavi","kirmizi", "beyaz", "mavi") #HATA

# %%
aa_set ={"mavi","kirmizi", "beyaz", "mavi"}
print(type(aa_set))
# Out:
# <class 'set'>

# %%
set_a = set("fistik")
set_b =set("findik")

# %%
set_a - set_b
# Out:
# {'s', 't'}

# %%
set_a.difference_update(set_b)
set_a
# Out:
# {'s', 't'}

# %%
print(set_a)
# Out:
# {'d', 'n'}

# %%
print(set_b)
# Out:
# {'s', 'k', 'f', 't', 'i'}

# %%
set_a = set("fistik")
set_b =set("findik")

# %%
set_a | set_b
# Out:
# {'d', 'f', 'i', 'k', 'n', 's', 't'}

# %%
set_a.update(set_b)

# %%
print(set_a)
# Out:
# {'s', 'k', 'f', 'd', 'n', 't', 'i'}

# %%
print(set_a)
# Out:
# {'i', 'k', 'f', 's', 't'}

# %%
set_a.p

# %%
print("3"+"3")
# Out:
# 33

# %%
set(1,2,3)

# %%
set_2 = {1,5,2.0,4,1.0,2}

# %%
set_stringlerile = {"ali","veli","hasan"}
type(set_stringlerile)
# Out:
# set

# %%
set(["mavi","kirmizi", "beyaz", "mavi"])
# Out:
# {'beyaz', 'kirmizi', 'mavi'}

# %%
aa = {"mavi","kirmizi", "beyaz", "mavi"}

# %%
type(aa)
# Out:
# set

# %%
empty_set= {}
empty_set
# Out:
# {}

# %%
type(empty_set)
# Out:
# dict

# %%
{"mavi", "sari","kirmizi"}
# Out:
# set

# %%
x = (24/2) - (2**(1*8/2)/2)
x
# Out:
# 4.0

# %%
s1 = {1,2,3,4,5,6,6,6}
print(type(s1))
# Out:
# <class 'set'>

# %%
print(s1)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
len('Techpro is the best course in the world'.split())
# Out:
# 8

# %%
import random

# %%
random.seed(95)
random.random()
# Out:
# 0.7601614783097744

# %%
random.randint(0,4)
# Out:
# 4

# %%
import random
sayı = random.randint(0,100)
sayaç = 0
while True:
    tahmin = int(input("Bir sayı girin"))
    
    if sayı < tahmin:
        print(f"Girdiğiniz sayı {tahmin}. Tahminini azalt")
        sayaç += 1
    elif sayı > tahmin:
        print(f"Girdiğiniz sayı {tahmin}. Tahminini arttır")
        sayaç += 1
    else:
        print(f"Girdiğiniz sayı {tahmin}.Bravo. Doğru tahmin")
        sayaç += 1
        break
print(f"{sayaç} denemede bildin")
# Out:
# Girdiğiniz sayı 16. Tahminini azalt
# Girdiğiniz sayı 9. Tahminini arttır
# Girdiğiniz sayı 5. Tahminini arttır
# Girdiğiniz sayı 13. Tahminini azalt
# Girdiğiniz sayı 11. Tahminini azalt
# Girdiğiniz sayı 10.Bravo. Doğru tahmin
# 6 denemede bildin
